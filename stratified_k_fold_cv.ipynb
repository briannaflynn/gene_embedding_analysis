# %% [markdown]
# ### Testing approach for protein-complex aware train / test split for cross-validation

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import random
import itertools

def generate_fast_dummy_gene_complex_data(
    n_genes=100,
    n_complexes=20,
    n_pairs=1000,
    pos_fraction=0.3,
    random_state=42
):
    random.seed(random_state)
    np.random.seed(random_state)

    # Step 1: Generate genes and assign to complexes
    genes = [f"GENE{i}" for i in range(n_genes)]
    complexes = [f"Complex_{i}" for i in range(n_complexes)]

    gene_to_complex = {
        gene: random.choice(complexes)
        for gene in genes
    }

    complex_map = pd.DataFrame({
        "Gene": list(gene_to_complex.keys()),
        "Complex": list(gene_to_complex.values())
    })

    # Step 2: Build all gene pairs
    complex_to_genes = complex_map.groupby("Complex")["Gene"].apply(list)

    # Positive pairs: same complex
    positive_pairs = []
    for genes_in_complex in complex_to_genes:
        pairs = list(itertools.combinations(sorted(genes_in_complex), 2))
        positive_pairs.extend(pairs)

    # Sample positive pairs
    n_pos = int(n_pairs * pos_fraction)
    pos_sample = random.sample(positive_pairs, min(n_pos, len(positive_pairs)))

    # Negative pairs: different complexes
    all_pairs = list(itertools.combinations(sorted(genes), 2))
    positive_set = set(pos_sample)
    negative_pairs = [pair for pair in all_pairs if gene_to_complex[pair[0]] != gene_to_complex[pair[1]]]
    n_neg = n_pairs - len(pos_sample)
    neg_sample = random.sample(negative_pairs, min(n_neg, len(negative_pairs)))

    # Build final DataFrame
    data = pos_sample + neg_sample
    labels = [1] * len(pos_sample) + [0] * len(neg_sample)

    df_pairs = pd.DataFrame(data, columns=["Gene_A", "Gene_B"])
    df_pairs["Label"] = labels

    return df_pairs, complex_map

def assign_complex_to_row(df, complex_map):
    """Map each gene pair to a shared complex, or unique ID if they differ."""
    # Merge complex info
    df = df.copy()
    complex_map = complex_map.rename(columns={'Gene': 'Gene_A', 'Complex': 'Complex_A'})
    df = df.merge(complex_map, on='Gene_A', how='left')

    complex_map = complex_map.rename(columns={'Gene_A': 'Gene_B', 'Complex_A': 'Complex_B'})
    df = df.merge(complex_map, on='Gene_B', how='left')

    def determine_group(row):
        if pd.notna(row['Complex_A']) and row['Complex_A'] == row['Complex_B']:
            return row['Complex_A']
        else:
            return f"UNRELATED_{hash(frozenset([row['Complex_A'], row['Complex_B']]))}"

    df['Complex_Group'] = df.apply(determine_group, axis=1)
    return df

def stratified_split_by_complex(df, test_size=0.2, random_state=42):
    """
    Ensure no overlapping complexes between train and test.
    """
    df = df.copy()
    unique_complexes = df['Complex_Group'].unique()

    # Stratify on whether the complex group label is 'in complex' or not
    # You could instead stratify based on counts or labels depending on balance
    stratify_labels = df.drop_duplicates('Complex_Group')[['Complex_Group', 'Label']].set_index('Complex_Group').reindex(unique_complexes)['Label'].fillna(0)

    train_complexes, test_complexes = train_test_split(
        unique_complexes,
        test_size=test_size,
        random_state=random_state,
        stratify=stratify_labels
    )

    train_df = df[df['Complex_Group'].isin(train_complexes)].reset_index(drop=True)
    test_df = df[df['Complex_Group'].isin(test_complexes)].reset_index(drop=True)

    return train_df, test_df

def extract_involved_complexes(row):
    complexes = set()
    if pd.notna(row['Complex_A']):
        complexes.add(row['Complex_A'])
    if pd.notna(row['Complex_B']):
        complexes.add(row['Complex_B'])
    return complexes

def stratified_split_by_complex_no_leak(df, test_size=0.2, random_state=42):
    df = df.copy()

    # Collect complex sets per row
    df['Complexes_Set'] = df.apply(extract_involved_complexes, axis=1)

    # Flatten to all unique complexes
    all_complexes = set().union(*df['Complexes_Set'])

    # Stratify based on presence of positive labels per complex (approx)
    complex_label_map = {}
    for complex_id in all_complexes:
        rows_with_complex = df[df['Complexes_Set'].apply(lambda x: complex_id in x)]
        complex_label_map[complex_id] = int(rows_with_complex['Label'].mean() > 0)

    complexes = list(complex_label_map.keys())
    labels = [complex_label_map[c] for c in complexes]

    # Split the complexes
    train_complexes, test_complexes = train_test_split(
        complexes,
        test_size=test_size,
        random_state=random_state,
        stratify=labels
    )

    train_complexes = set(train_complexes)
    test_complexes = set(test_complexes)

    # Filter rows where all involved complexes are in the same group
    train_df = df[df['Complexes_Set'].apply(lambda s: s.issubset(train_complexes))].reset_index(drop=True)
    test_df = df[df['Complexes_Set'].apply(lambda s: s.issubset(test_complexes))].reset_index(drop=True)

    return train_df, test_df

# %%
df = pd.DataFrame({
        'Gene_A': ['BRCA1', 'TP53', 'BRCA2', 'RAD51', 'MTOR', 'PIK3CA'],
        'Gene_B': ['BRCA2', 'MDM2', 'PALB2', 'RAD52', 'AKT1', 'AKT2'],
        'Label':   [1, 1, 1, 0, 1, 0]})

complex_map = pd.DataFrame({
        'Gene': ['BRCA1', 'BRCA2', 'PALB2', 'TP53', 'MDM2', 'RAD51', 'RAD52', 'MTOR', 'AKT1', 'PIK3CA'],
        'Complex': ['Complex1', 'Complex1', 'Complex1', 'Complex2', 'Complex2', 'Complex3', 'Complex4', 'Complex5', 'Complex5', 'Complex6']
    })

# %%
df
# Out:
#    Gene_A Gene_B  Label
# 0   BRCA1  BRCA2      1
# 1    TP53   MDM2      1
# 2   BRCA2  PALB2      1
# 3   RAD51  RAD52      0
# 4    MTOR   AKT1      1
# 5  PIK3CA   AKT2      0

# %%
complex_map
# Out:
#      Gene   Complex
# 0   BRCA1  Complex1
# 1   BRCA2  Complex1
# 2   PALB2  Complex1
# 3    TP53  Complex2
# 4    MDM2  Complex2
# 5   RAD51  Complex3
# 6   RAD52  Complex4
# 7    MTOR  Complex5
# 8    AKT1  Complex5
# 9  PIK3CA  Complex6

# %%
df, complex_map = generate_fast_dummy_gene_complex_data()

# %%
df
# Out:
#      Gene_A  Gene_B  Label
# 0    GENE44  GENE64      1
# 1    GENE23  GENE75      1
# 2    GENE46  GENE61      1
# 3    GENE35   GENE6      1
# 4    GENE64  GENE96      1
# ..      ...     ...    ...
# 995   GENE6  GENE64      0
# 996  GENE36  GENE97      0
# 997  GENE50  GENE57      0
# 998  GENE18  GENE65      0
# 999   GENE2  GENE90      0
#
# [1000 rows x 3 columns]

# %%
complex_map
# Out:
#       Gene     Complex
# 0    GENE0   Complex_3
# 1    GENE1   Complex_0
# 2    GENE2   Complex_8
# 3    GENE3   Complex_7
# 4    GENE4   Complex_7
# ..     ...         ...
# 95  GENE95  Complex_12
# 96  GENE96  Complex_14
# 97  GENE97   Complex_4
# 98  GENE98   Complex_8
# 99  GENE99   Complex_4
#
# [100 rows x 2 columns]

# %%
df_with_complex = assign_complex_to_row(df, complex_map)

# %%
df_with_complex
# Out:
#      Gene_A  Gene_B  Label   Complex_A   Complex_B  \
# 0    GENE44  GENE64      1  Complex_14  Complex_14
# 1    GENE23  GENE75      1   Complex_7   Complex_7
# 2    GENE46  GENE61      1   Complex_3   Complex_3
# 3    GENE35   GENE6      1   Complex_3   Complex_3
# 4    GENE64  GENE96      1  Complex_14  Complex_14
# ..      ...     ...    ...         ...         ...
# 995   GENE6  GENE64      0   Complex_3  Complex_14
# 996  GENE36  GENE97      0   Complex_2   Complex_4
# 997  GENE50  GENE57      0   Complex_9   Complex_7
# 998  GENE18  GENE65      0   Complex_0  Complex_11
# 999   GENE2  GENE90      0   Complex_8   Complex_6
#
#                       Complex_Group
# 0                        Complex_14
# 1                         Complex_7
# 2                         Complex_3
# 3                         Complex_3
# 4                        Complex_14
# ..                              ...
# 995  UNRELATED_-8900013985987075014
# 996  UNRELATED_-5499943997916966653
# 997    UNRELATED_-88597226039519464
# 998   UNRELATED_3652095148036549621
# 999  UNRELATED_-7338193683955946271
#
# [1000 rows x 6 columns]

# %%
train_df, test_df = stratified_split_by_complex(df_with_complex)

# %%
train_df
# Out:
#      Gene_A  Gene_B  Label   Complex_A   Complex_B  \
# 0    GENE44  GENE64      1  Complex_14  Complex_14
# 1    GENE23  GENE75      1   Complex_7   Complex_7
# 2    GENE46  GENE61      1   Complex_3   Complex_3
# 3    GENE35   GENE6      1   Complex_3   Complex_3
# 4    GENE64  GENE96      1  Complex_14  Complex_14
# ..      ...     ...    ...         ...         ...
# 775   GENE6  GENE64      0   Complex_3  Complex_14
# 776  GENE36  GENE97      0   Complex_2   Complex_4
# 777  GENE50  GENE57      0   Complex_9   Complex_7
# 778  GENE18  GENE65      0   Complex_0  Complex_11
# 779   GENE2  GENE90      0   Complex_8   Complex_6
#
#                       Complex_Group
# 0                        Complex_14
# 1                         Complex_7
# 2                         Complex_3
# 3                         Complex_3
# 4                        Complex_14
# ..                              ...
# 775  UNRELATED_-8900013985987075014
# 776  UNRELATED_-5499943997916966653
# 777    UNRELATED_-88597226039519464
# 778   UNRELATED_3652095148036549621
# 779  UNRELATED_-7338193683955946271
#
# [780 rows x 6 columns]

# %%
test_df
# Out:
#      Gene_A  Gene_B  Label   Complex_A   Complex_B  \
# 0     GENE5  GENE99      1   Complex_4   Complex_4
# 1    GENE31  GENE42      1   Complex_8   Complex_8
# 2    GENE70  GENE79      1   Complex_8   Complex_8
# 3     GENE2  GENE88      1   Complex_8   Complex_8
# 4    GENE14  GENE69      1   Complex_6   Complex_6
# ..      ...     ...    ...         ...         ...
# 215  GENE40  GENE89      0  Complex_11   Complex_2
# 216   GENE1  GENE31      0   Complex_0   Complex_8
# 217  GENE46  GENE91      0   Complex_3  Complex_18
# 218  GENE10  GENE27      0  Complex_13   Complex_0
# 219  GENE13  GENE61      0   Complex_2   Complex_3
#
#                       Complex_Group
# 0                         Complex_4
# 1                         Complex_8
# 2                         Complex_8
# 3                         Complex_8
# 4                         Complex_6
# ..                              ...
# 215  UNRELATED_-1112816051940215057
# 216   UNRELATED_7055619691820458489
# 217  UNRELATED_-6345802722480175068
# 218   UNRELATED_2807033227285835388
# 219   UNRELATED_1810200194389755326
#
# [220 rows x 6 columns]

# %%
## perhaps want to change this so that even the 'UNRELATED' complexes are not in the test set

# %%
train, test = stratified_split_by_complex_no_leak(df_with_complex)

# %%
train
# Out:
#      Gene_A  Gene_B  Label   Complex_A   Complex_B  \
# 0    GENE44  GENE64      1  Complex_14  Complex_14
# 1    GENE23  GENE75      1   Complex_7   Complex_7
# 2    GENE46  GENE61      1   Complex_3   Complex_3
# 3    GENE35   GENE6      1   Complex_3   Complex_3
# 4    GENE64  GENE96      1  Complex_14  Complex_14
# ..      ...     ...    ...         ...         ...
# 695  GENE13  GENE61      0   Complex_2   Complex_3
# 696   GENE6  GENE64      0   Complex_3  Complex_14
# 697  GENE36  GENE97      0   Complex_2   Complex_4
# 698  GENE50  GENE57      0   Complex_9   Complex_7
# 699  GENE18  GENE65      0   Complex_0  Complex_11
#
#                       Complex_Group            Complexes_Set
# 0                        Complex_14             {Complex_14}
# 1                         Complex_7              {Complex_7}
# 2                         Complex_3              {Complex_3}
# 3                         Complex_3              {Complex_3}
# 4                        Complex_14             {Complex_14}
# ..                              ...                      ...
# 695   UNRELATED_1810200194389755326   {Complex_2, Complex_3}
# 696  UNRELATED_-8900013985987075014  {Complex_3, Complex_14}
# 697  UNRELATED_-5499943997916966653   {Complex_2, Complex_4}
# 698    UNRELATED_-88597226039519464   {Complex_7, Complex_9}
# 699   UNRELATED_3652095148036549621  {Complex_0, Complex_11}
#
# [700 rows x 7 columns]

# %%
train[train['Complex_A']=='Complex_6']
# Out:
# Empty DataFrame
# Columns: [Gene_A, Gene_B, Label, Complex_A, Complex_B, Complex_Group, Complexes_Set]
# Index: []

# %%
train[train['Complex_B']=='Complex_6']
# Out:
# Empty DataFrame
# Columns: [Gene_A, Gene_B, Label, Complex_A, Complex_B, Complex_Group, Complexes_Set]
# Index: []

# %%
test
# Out:
#     Gene_A  Gene_B  Label   Complex_A   Complex_B  \
# 0   GENE10  GENE22      1  Complex_13  Complex_13
# 1   GENE14  GENE69      1   Complex_6   Complex_6
# 2   GENE54  GENE93      1   Complex_6   Complex_6
# 3   GENE28  GENE73      1   Complex_5   Complex_5
# 4   GENE17  GENE72      1  Complex_19  Complex_19
# 5   GENE17  GENE51      1  Complex_19  Complex_19
# 6   GENE20  GENE54      1   Complex_6   Complex_6
# 7   GENE20  GENE33      1   Complex_6   Complex_6
# 8   GENE66  GENE76      1   Complex_5   Complex_5
# 9   GENE28  GENE76      1   Complex_5   Complex_5
# 10  GENE33  GENE93      1   Complex_6   Complex_6
# 11  GENE14  GENE93      1   Complex_6   Complex_6
# 12  GENE10  GENE29      1  Complex_13  Complex_13
# 13  GENE22  GENE29      1  Complex_13  Complex_13
# 14  GENE73  GENE76      1   Complex_5   Complex_5
# 15  GENE54  GENE90      1   Complex_6   Complex_6
# 16  GENE41  GENE72      1  Complex_19  Complex_19
# 17  GENE14  GENE54      1   Complex_6   Complex_6
# 18  GENE90  GENE93      1   Complex_6   Complex_6
# 19  GENE66  GENE73      1   Complex_5   Complex_5
# 20  GENE28  GENE66      1   Complex_5   Complex_5
# 21  GENE51  GENE72      1  Complex_19  Complex_19
# 22  GENE33  GENE54      1   Complex_6   Complex_6
# 23  GENE17  GENE41      1  Complex_19  Complex_19
# 24  GENE20  GENE90      1   Complex_6   Complex_6
# 25  GENE69  GENE93      1   Complex_6   Complex_6
# 26  GENE33  GENE69      1   Complex_6   Complex_6
# 27  GENE20  GENE69      1   Complex_6   Complex_6
# 28  GENE41  GENE51      1  Complex_19  Complex_19
# 29  GENE14  GENE33      1   Complex_6   Complex_6
# 30  GENE20  GENE93      1   Complex_6   Complex_6
# 31  GENE14  GENE90      1   Complex_6   Complex_6
# 32  GENE69  GENE90      1   Complex_6   Complex_6
# 33  GENE33  GENE90      1   Complex_6   Complex_6
# 34  GENE54  GENE69      1   Complex_6   Complex_6
# 35  GENE14  GENE20      1   Complex_6   Complex_6
# 36  GENE14  GENE51      0   Complex_6  Complex_19
# 37  GENE14  GENE22      0   Complex_6  Complex_13
# 38  GENE73  GENE93      0   Complex_5   Complex_6
# 39  GENE17  GENE73      0  Complex_19   Complex_5
# 40  GENE14  GENE73      0   Complex_6   Complex_5
# 41  GENE54  GENE76      0   Complex_6   Complex_5
# 42  GENE29  GENE90      0  Complex_13   Complex_6
# 43  GENE20  GENE72      0   Complex_6  Complex_19
# 44  GENE20  GENE73      0   Complex_6   Complex_5
# 45  GENE10  GENE41      0  Complex_13  Complex_19
# 46  GENE10  GENE72      0  Complex_13  Complex_19
# 47  GENE76  GENE93      0   Complex_5   Complex_6
# 48  GENE17  GENE22      0  Complex_19  Complex_13
# 49  GENE33  GENE66      0   Complex_6   Complex_5
# 50  GENE14  GENE41      0   Complex_6  Complex_19
# 51  GENE10  GENE33      0  Complex_13   Complex_6
# 52  GENE17  GENE54      0  Complex_19   Complex_6
# 53  GENE54  GENE72      0   Complex_6  Complex_19
# 54  GENE33  GENE51      0   Complex_6  Complex_19
#
#                      Complex_Group             Complexes_Set
# 0                       Complex_13              {Complex_13}
# 1                        Complex_6               {Complex_6}
# 2                        Complex_6               {Complex_6}
# 3                        Complex_5               {Complex_5}
# 4                       Complex_19              {Complex_19}
# 5                       Complex_19              {Complex_19}
# 6                        Complex_6               {Complex_6}
# 7                        Complex_6               {Complex_6}
# 8                        Complex_5               {Complex_5}
# 9                        Complex_5               {Complex_5}
# 10                       Complex_6               {Complex_6}
# 11                       Complex_6               {Complex_6}
# 12                      Complex_13              {Complex_13}
# 13                      Complex_13              {Complex_13}
# 14                       Complex_5               {Complex_5}
# 15                       Complex_6               {Complex_6}
# 16                      Complex_19              {Complex_19}
# 17                       Complex_6               {Complex_6}
# 18                       Complex_6               {Complex_6}
# 19                       Complex_5               {Complex_5}
# 20                       Complex_5               {Complex_5}
# 21                      Complex_19              {Complex_19}
# 22                       Complex_6               {Complex_6}
# 23                      Complex_19              {Complex_19}
# 24                       Complex_6               {Complex_6}
# 25                       Complex_6               {Complex_6}
# 26                       Complex_6               {Complex_6}
# 27                       Complex_6               {Complex_6}
# 28                      Complex_19              {Complex_19}
# 29                       Complex_6               {Complex_6}
# 30                       Complex_6               {Complex_6}
# 31                       Complex_6               {Complex_6}
# 32                       Complex_6               {Complex_6}
# 33                       Complex_6               {Complex_6}
# 34                       Complex_6               {Complex_6}
# 35                       Complex_6               {Complex_6}
# 36   UNRELATED_8211481018379356006   {Complex_6, Complex_19}
# 37   UNRELATED_1925057138913754820   {Complex_6, Complex_13}
# 38   UNRELATED_-910670142666455851    {Complex_5, Complex_6}
# 39  UNRELATED_-1112590311631191010   {Complex_5, Complex_19}
# 40   UNRELATED_-910670142666455851    {Complex_5, Complex_6}
# 41   UNRELATED_-910670142666455851    {Complex_5, Complex_6}
# 42   UNRELATED_1925057138913754820   {Complex_6, Complex_13}
# 43   UNRELATED_8211481018379356006   {Complex_6, Complex_19}
# 44   UNRELATED_-910670142666455851    {Complex_5, Complex_6}
# 45  UNRELATED_-4320278566154756229  {Complex_19, Complex_13}
# 46  UNRELATED_-4320278566154756229  {Complex_19, Complex_13}
# 47   UNRELATED_-910670142666455851    {Complex_5, Complex_6}
# 48  UNRELATED_-4320278566154756229  {Complex_19, Complex_13}
# 49   UNRELATED_-910670142666455851    {Complex_5, Complex_6}
# 50   UNRELATED_8211481018379356006   {Complex_6, Complex_19}
# 51   UNRELATED_1925057138913754820   {Complex_6, Complex_13}
# 52   UNRELATED_8211481018379356006   {Complex_6, Complex_19}
# 53   UNRELATED_8211481018379356006   {Complex_6, Complex_19}
# 54   UNRELATED_8211481018379356006   {Complex_6, Complex_19}

# %%
test[test['Complex_A']=='Complex_6']
# Out:
#     Gene_A  Gene_B  Label  Complex_A   Complex_B  \
# 1   GENE14  GENE69      1  Complex_6   Complex_6
# 2   GENE54  GENE93      1  Complex_6   Complex_6
# 6   GENE20  GENE54      1  Complex_6   Complex_6
# 7   GENE20  GENE33      1  Complex_6   Complex_6
# 10  GENE33  GENE93      1  Complex_6   Complex_6
# 11  GENE14  GENE93      1  Complex_6   Complex_6
# 15  GENE54  GENE90      1  Complex_6   Complex_6
# 17  GENE14  GENE54      1  Complex_6   Complex_6
# 18  GENE90  GENE93      1  Complex_6   Complex_6
# 22  GENE33  GENE54      1  Complex_6   Complex_6
# 24  GENE20  GENE90      1  Complex_6   Complex_6
# 25  GENE69  GENE93      1  Complex_6   Complex_6
# 26  GENE33  GENE69      1  Complex_6   Complex_6
# 27  GENE20  GENE69      1  Complex_6   Complex_6
# 29  GENE14  GENE33      1  Complex_6   Complex_6
# 30  GENE20  GENE93      1  Complex_6   Complex_6
# 31  GENE14  GENE90      1  Complex_6   Complex_6
# 32  GENE69  GENE90      1  Complex_6   Complex_6
# 33  GENE33  GENE90      1  Complex_6   Complex_6
# 34  GENE54  GENE69      1  Complex_6   Complex_6
# 35  GENE14  GENE20      1  Complex_6   Complex_6
# 36  GENE14  GENE51      0  Complex_6  Complex_19
# 37  GENE14  GENE22      0  Complex_6  Complex_13
# 40  GENE14  GENE73      0  Complex_6   Complex_5
# 41  GENE54  GENE76      0  Complex_6   Complex_5
# 43  GENE20  GENE72      0  Complex_6  Complex_19
# 44  GENE20  GENE73      0  Complex_6   Complex_5
# 49  GENE33  GENE66      0  Complex_6   Complex_5
# 50  GENE14  GENE41      0  Complex_6  Complex_19
# 53  GENE54  GENE72      0  Complex_6  Complex_19
# 54  GENE33  GENE51      0  Complex_6  Complex_19
#
#                     Complex_Group            Complexes_Set
# 1                       Complex_6              {Complex_6}
# 2                       Complex_6              {Complex_6}
# 6                       Complex_6              {Complex_6}
# 7                       Complex_6              {Complex_6}
# 10                      Complex_6              {Complex_6}
# 11                      Complex_6              {Complex_6}
# 15                      Complex_6              {Complex_6}
# 17                      Complex_6              {Complex_6}
# 18                      Complex_6              {Complex_6}
# 22                      Complex_6              {Complex_6}
# 24                      Complex_6              {Complex_6}
# 25                      Complex_6              {Complex_6}
# 26                      Complex_6              {Complex_6}
# 27                      Complex_6              {Complex_6}
# 29                      Complex_6              {Complex_6}
# 30                      Complex_6              {Complex_6}
# 31                      Complex_6              {Complex_6}
# 32                      Complex_6              {Complex_6}
# 33                      Complex_6              {Complex_6}
# 34                      Complex_6              {Complex_6}
# 35                      Complex_6              {Complex_6}
# 36  UNRELATED_8211481018379356006  {Complex_6, Complex_19}
# 37  UNRELATED_1925057138913754820  {Complex_6, Complex_13}
# 40  UNRELATED_-910670142666455851   {Complex_5, Complex_6}
# 41  UNRELATED_-910670142666455851   {Complex_5, Complex_6}
# 43  UNRELATED_8211481018379356006  {Complex_6, Complex_19}
# 44  UNRELATED_-910670142666455851   {Complex_5, Complex_6}
# 49  UNRELATED_-910670142666455851   {Complex_5, Complex_6}
# 50  UNRELATED_8211481018379356006  {Complex_6, Complex_19}
# 53  UNRELATED_8211481018379356006  {Complex_6, Complex_19}
# 54  UNRELATED_8211481018379356006  {Complex_6, Complex_19}

# %%
test[test['Complex_B']=='Complex_6']
# Out:
#     Gene_A  Gene_B  Label   Complex_A  Complex_B  \
# 1   GENE14  GENE69      1   Complex_6  Complex_6
# 2   GENE54  GENE93      1   Complex_6  Complex_6
# 6   GENE20  GENE54      1   Complex_6  Complex_6
# 7   GENE20  GENE33      1   Complex_6  Complex_6
# 10  GENE33  GENE93      1   Complex_6  Complex_6
# 11  GENE14  GENE93      1   Complex_6  Complex_6
# 15  GENE54  GENE90      1   Complex_6  Complex_6
# 17  GENE14  GENE54      1   Complex_6  Complex_6
# 18  GENE90  GENE93      1   Complex_6  Complex_6
# 22  GENE33  GENE54      1   Complex_6  Complex_6
# 24  GENE20  GENE90      1   Complex_6  Complex_6
# 25  GENE69  GENE93      1   Complex_6  Complex_6
# 26  GENE33  GENE69      1   Complex_6  Complex_6
# 27  GENE20  GENE69      1   Complex_6  Complex_6
# 29  GENE14  GENE33      1   Complex_6  Complex_6
# 30  GENE20  GENE93      1   Complex_6  Complex_6
# 31  GENE14  GENE90      1   Complex_6  Complex_6
# 32  GENE69  GENE90      1   Complex_6  Complex_6
# 33  GENE33  GENE90      1   Complex_6  Complex_6
# 34  GENE54  GENE69      1   Complex_6  Complex_6
# 35  GENE14  GENE20      1   Complex_6  Complex_6
# 38  GENE73  GENE93      0   Complex_5  Complex_6
# 42  GENE29  GENE90      0  Complex_13  Complex_6
# 47  GENE76  GENE93      0   Complex_5  Complex_6
# 51  GENE10  GENE33      0  Complex_13  Complex_6
# 52  GENE17  GENE54      0  Complex_19  Complex_6
#
#                     Complex_Group            Complexes_Set
# 1                       Complex_6              {Complex_6}
# 2                       Complex_6              {Complex_6}
# 6                       Complex_6              {Complex_6}
# 7                       Complex_6              {Complex_6}
# 10                      Complex_6              {Complex_6}
# 11                      Complex_6              {Complex_6}
# 15                      Complex_6              {Complex_6}
# 17                      Complex_6              {Complex_6}
# 18                      Complex_6              {Complex_6}
# 22                      Complex_6              {Complex_6}
# 24                      Complex_6              {Complex_6}
# 25                      Complex_6              {Complex_6}
# 26                      Complex_6              {Complex_6}
# 27                      Complex_6              {Complex_6}
# 29                      Complex_6              {Complex_6}
# 30                      Complex_6              {Complex_6}
# 31                      Complex_6              {Complex_6}
# 32                      Complex_6              {Complex_6}
# 33                      Complex_6              {Complex_6}
# 34                      Complex_6              {Complex_6}
# 35                      Complex_6              {Complex_6}
# 38  UNRELATED_-910670142666455851   {Complex_5, Complex_6}
# 42  UNRELATED_1925057138913754820  {Complex_6, Complex_13}
# 47  UNRELATED_-910670142666455851   {Complex_5, Complex_6}
# 51  UNRELATED_1925057138913754820  {Complex_6, Complex_13}
# 52  UNRELATED_8211481018379356006  {Complex_6, Complex_19}
